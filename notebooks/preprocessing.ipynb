# %%
import pandas as pd

# %%
df = pd.read_csv("./../data/integrated-data/residential_panel_data.csv")
df.head()
# Out:
#    Year        End_Use            Fuel_Technology  Energy_ktoe  Population  \
# 0  2000        Cooking                Electricity  2603.127898  82163475.0
# 1  2000        Cooking                Natural gas    75.099968  82163475.0
# 2  2000  Space cooling           Air conditioning    49.765895  82163475.0
# 3  2000  Space heating  Advanced electric heating    91.031836  82163475.0
# 4  2000  Space heating                    Biomass  3840.225618  82163475.0
#
#    Households  Inhabitants per household      HDD   CDD          GDP  \
# 0  38136234.0                   2.154473  3636.65  1.15  3295140.008
# 1  38136234.0                   2.154473  3636.65  1.15  3295140.008
# 2  38136234.0                   2.154473  3636.65  1.15  3295140.008
# 3  38136234.0                   2.154473  3636.65  1.15  3295140.008
# 4  38136234.0                   2.154473  3636.65  1.15  3295140.008
#
#    Expenditure
# 0  1853218.384
# 1  1853218.384
# 2  1853218.384
# 3  1853218.384
# 4  1853218.384

# %%
df.isna().sum()
# Out:
# Year                         0
# End_Use                      0
# Fuel_Technology              0
# Energy_ktoe                  0
# Population                   0
# Households                   0
# Inhabitants per household    0
# HDD                          0
# CDD                          0
# GDP                          0
# Expenditure                  0
# dtype: int64

# %%
df.nunique()
# Out:
# Year                          24
# End_Use                        4
# Fuel_Technology               13
# Energy_ktoe                  499
# Population                    24
# Households                    24
# Inhabitants per household     24
# HDD                           24
# CDD                           24
# GDP                           24
# Expenditure                   24
# dtype: int64

# %%
df.dtypes
# Out:
# Year                           int64
# End_Use                       object
# Fuel_Technology               object
# Energy_ktoe                  float64
# Population                   float64
# Households                   float64
# Inhabitants per household    float64
# HDD                          float64
# CDD                          float64
# GDP                          float64
# Expenditure                  float64
# dtype: object

# %%
df_lag = df.copy()
df_lag['Energy_Lag1'] = df_lag.groupby(['End_Use', 'Fuel_Technology'])['Energy_ktoe'].shift(1)

# %%
df_processed = pd.get_dummies(df, columns=['Fuel_Technology'], prefix='Tech')
df_lag_processed = pd.get_dummies(df_lag, columns=['Fuel_Technology'], prefix='Tech')

# %%
df_processed
# Out:
#      Year        End_Use  Energy_ktoe  Population  Households  \
# 0    2000        Cooking  2603.127898  82163475.0  38136234.0
# 1    2000        Cooking    75.099968  82163475.0  38136234.0
# 2    2000  Space cooling    49.765895  82163475.0  38136234.0
# 3    2000  Space heating    91.031836  82163475.0  38136234.0
# 4    2000  Space heating  3840.225618  82163475.0  38136234.0
# ..    ...            ...          ...         ...         ...
# 499  2023  Water heating   955.953610  83118501.0  41086753.0
# 500  2023  Water heating     3.206848  83118501.0  41086753.0
# 501  2023  Water heating    86.987505  83118501.0  41086753.0
# 502  2023  Water heating  3267.809027  83118501.0  41086753.0
# 503  2023  Water heating   749.331212  83118501.0  41086753.0
#
#      Inhabitants per household      HDD    CDD          GDP  Expenditure  ...  \
# 0                     2.154473  3636.65   1.15  3295140.008  1853218.384  ...
# 1                     2.154473  3636.65   1.15  3295140.008  1853218.384  ...
# 2                     2.154473  3636.65   1.15  3295140.008  1853218.384  ...
# 3                     2.154473  3636.65   1.15  3295140.008  1853218.384  ...
# 4                     2.154473  3636.65   1.15  3295140.008  1853218.384  ...
# ..                         ...      ...    ...          ...          ...  ...
# 499                   2.023000  3221.84  51.71  4219310.000  2218511.000  ...
# 500                   2.023000  3221.84  51.71  4219310.000  2218511.000  ...
# 501                   2.023000  3221.84  51.71  4219310.000  2218511.000  ...
# 502                   2.023000  3221.84  51.71  4219310.000  2218511.000  ...
# 503                   2.023000  3221.84  51.71  4219310.000  2218511.000  ...
#
#      Tech_Conventional electric heating  Tech_Diesel oil  \
# 0                                 False            False
# 1                                 False            False
# 2                                 False            False
# 3                                 False            False
# 4                                 False            False
# ..                                  ...              ...
# 499                               False            False
# 500                               False            False
# 501                               False            False
# 502                               False            False
# 503                               False            False
#
#      Tech_Distributed heat  Tech_Electricity  Tech_Electricity in circulation  \
# 0                    False              True                            False
# 1                    False             False                            False
# 2                    False             False                            False
# 3                    False             False                            False
# 4                    False             False                            False
# ..                     ...               ...                              ...
# 499                  False              True                            False
# 500                  False             False                            False
# 501                  False             False                            False
# 502                  False             False                            False
# 503                  False             False                            False
#
#      Tech_Geothermal  Tech_Liquified petroleum gas (LPG)  Tech_Natural gas  \
# 0              False                               False             False
# 1              False                               False              True
# 2              False                               False             False
# 3              False                               False             False
# 4              False                               False             False
# ..               ...                                 ...               ...
# 499            False                               False             False
# 500             True                               False             False
# 501            False                                True             False
# 502            False                               False              True
# 503            False                               False             False
#
#      Tech_Solar  Tech_Solids
# 0         False        False
# 1         False        False
# 2         False        False
# 3         False        False
# 4         False        False
# ..          ...          ...
# 499       False        False
# 500       False        False
# 501       False        False
# 502       False        False
# 503        True        False
#
# [504 rows x 23 columns]

# %%
df_lag_processed
# Out:
#      Year        End_Use  Energy_ktoe  Population  Households  \
# 0    2000        Cooking  2603.127898  82163475.0  38136234.0
# 1    2000        Cooking    75.099968  82163475.0  38136234.0
# 2    2000  Space cooling    49.765895  82163475.0  38136234.0
# 3    2000  Space heating    91.031836  82163475.0  38136234.0
# 4    2000  Space heating  3840.225618  82163475.0  38136234.0
# ..    ...            ...          ...         ...         ...
# 499  2023  Water heating   955.953610  83118501.0  41086753.0
# 500  2023  Water heating     3.206848  83118501.0  41086753.0
# 501  2023  Water heating    86.987505  83118501.0  41086753.0
# 502  2023  Water heating  3267.809027  83118501.0  41086753.0
# 503  2023  Water heating   749.331212  83118501.0  41086753.0
#
#      Inhabitants per household      HDD    CDD          GDP  Expenditure  ...  \
# 0                     2.154473  3636.65   1.15  3295140.008  1853218.384  ...
# 1                     2.154473  3636.65   1.15  3295140.008  1853218.384  ...
# 2                     2.154473  3636.65   1.15  3295140.008  1853218.384  ...
# 3                     2.154473  3636.65   1.15  3295140.008  1853218.384  ...
# 4                     2.154473  3636.65   1.15  3295140.008  1853218.384  ...
# ..                         ...      ...    ...          ...          ...  ...
# 499                   2.023000  3221.84  51.71  4219310.000  2218511.000  ...
# 500                   2.023000  3221.84  51.71  4219310.000  2218511.000  ...
# 501                   2.023000  3221.84  51.71  4219310.000  2218511.000  ...
# 502                   2.023000  3221.84  51.71  4219310.000  2218511.000  ...
# 503                   2.023000  3221.84  51.71  4219310.000  2218511.000  ...
#
#      Tech_Conventional electric heating  Tech_Diesel oil  \
# 0                                 False            False
# 1                                 False            False
# 2                                 False            False
# 3                                 False            False
# 4                                 False            False
# ..                                  ...              ...
# 499                               False            False
# 500                               False            False
# 501                               False            False
# 502                               False            False
# 503                               False            False
#
#      Tech_Distributed heat  Tech_Electricity  Tech_Electricity in circulation  \
# 0                    False              True                            False
# 1                    False             False                            False
# 2                    False             False                            False
# 3                    False             False                            False
# 4                    False             False                            False
# ..                     ...               ...                              ...
# 499                  False              True                            False
# 500                  False             False                            False
# 501                  False             False                            False
# 502                  False             False                            False
# 503                  False             False                            False
#
#      Tech_Geothermal  Tech_Liquified petroleum gas (LPG)  Tech_Natural gas  \
# 0              False                               False             False
# 1              False                               False              True
# 2              False                               False             False
# 3              False                               False             False
# 4              False                               False             False
# ..               ...                                 ...               ...
# 499            False                               False             False
# 500             True                               False             False
# 501            False                                True             False
# 502            False                               False              True
# 503            False                               False             False
#
#      Tech_Solar  Tech_Solids
# 0         False        False
# 1         False        False
# 2         False        False
# 3         False        False
# 4         False        False
# ..          ...          ...
# 499       False        False
# 500       False        False
# 501       False        False
# 502       False        False
# 503        True        False
#
# [504 rows x 24 columns]

# %%
df_lag_clean = df_lag_processed.dropna(subset=['Energy_Lag1'])

# %%
train_df = df_processed[df_processed['Year'] <= 2021].copy()
test_df  = df_processed[df_processed['Year'] > 2021].copy()

train_df_lag = df_lag_clean[df_lag_clean['Year'] <= 2021].copy()
test_df_lag  = df_lag_clean[df_lag_clean['Year'] > 2021].copy()

# %%
train_df.to_csv("./../data/preprocessed/train.csv", index=False)
test_df.to_csv("./../data/preprocessed/test.csv", index=False)

train_df_lag.to_csv("./../data/preprocessed/train_lag.csv", index=False)
test_df_lag.to_csv("./../data/preprocessed/test_lag.csv", index=False)
